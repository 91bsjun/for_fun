# %% [markdown]
# <a href="https://colab.research.google.com/github/91bsjun/for_fun/blob/master/%EB%AC%B4%EB%A7%A4zero_LABU_%EB%B3%B5%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 복리로 무한매수 zero 진행 시 시드변화 (2017. 10. 6 ~ 2021. 3. 29)

# %% [markdown]
# ## 상세 내역

# %%
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#    시드머니 소진
#    Today:  2017-12-29
#    Open :  82.32
#    Close:  77.85
#    AVG. :  75.24
#    P&L. :  4672.80 (9.41 %)
#    Seed :  54672.80
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# 전날까지 매수 현황
#      #        Date   Open  Close   High  Quantity  Total quantity    Amount  Avg. price  Target price   Profit  Profit (%)  Seed usage (%)
# 0    1  2017-10-06  90.00  90.43  92.56         6               6    542.58       90.43         99.47     0.00        0.00            1.09
# 1    2  2017-10-09  91.18  88.65  91.41        12              18   1606.38       89.24         98.16   -10.62       -0.66            3.21
# 2    3  2017-10-10  89.43  88.50  89.91        12              30   2668.38       88.95         97.85   -13.50       -0.51            5.34
# 3    4  2017-10-11  88.23  87.78  89.00        12              42   3721.74       88.61         97.47   -34.86       -0.94            7.44
# ...
